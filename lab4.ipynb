# %%
# слова которые даны "выходит" и "играть"

# %%
from sys import argv
import numpy as np
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

np.random.seed(42)
torch.manual_seed(42)

def generate(
            model, tok, text,
            do_sample=True, max_length=300, repetition_penalty=5.0,
            top_k=5, top_p=0.95, temperature=1,
            num_beams=None,
            no_repeat_ngram_size=3
            ):
    input_ids = tok.encode(text, return_tensors="pt")
    out = model.generate(
        input_ids,
        max_length=max_length,
        repetition_penalty=repetition_penalty,
        do_sample=do_sample,
        top_k=top_k, top_p=top_p, temperature=temperature,
        num_beams=num_beams, no_repeat_ngram_size=no_repeat_ngram_size
    )
    return list(map(tok.decode, out))

def load_tokenizer_and_model(model_name_or_path):
    return GPT2Tokenizer.from_pretrained(model_name_or_path), GPT2LMHeadModel.from_pretrained(model_name_or_path)

tok, model = load_tokenizer_and_model("sberbank-ai/rugpt3large_based_on_gpt2")

bb = "Когда релиз ГТА5"
generated = generate(model, tok, bb, num_beams=10)
print(generated[0])
# Out:
# Когда релиз ГТА5 состоится на PC?
# Да, уже в этом году.<s>
# ГТА 5 выйдет на пк или только на консолях?
# На ПК конечно же!<s>
# Какие у вас ассоциации со словом "свобода"?
# Свобода - это когда ты можешь делать то, что хочешь и не зависеть ни от кого. Свобода - это отсутствие страха перед кем бы то ни было. А еще свобода - это возможность жить так, как тебе хочется. Но при этом надо быть готовым к тому, что кто-то может диктовать свои условия. Например, родители могут заставить тебя ходить в ту школу, которую ты считаешь для себя неприемлемой. Или твой начальник может уволить тебя с работы по причине того, что ты слишком много времени проводишь за компьютером. И т. д., и т. п. В общем, свобода - понятие относительное. У каждого свое представление о том, что такое свобода. Кто-то считает ее безграничной, а кому-то кажется, что она ограничена определенными рамками. Лично я считаю, что свободу нельзя измерять какими-то конкретными критериями. Она либо есть, либо ее нет. Поэтому каждый человек должен сам для себя решить, чего он хочет добиться в своей жизни. Для меня свобода заключается в том, чтобы иметь возможность заниматься тем, что мне нравится. Я хочу научиться играть на гитаре, кататься на скейтборде, танцевать хип-хоп (не путать с хастлом),
